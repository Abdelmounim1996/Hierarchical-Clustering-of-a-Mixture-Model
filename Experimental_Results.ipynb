# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdelmounim1996/Hierarchical-Clustering-of-a-Mixture-Model/blob/master/Experimental_Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Abdelmounim1996/Hierarchical-Clustering-of-a-Mixture-Model
# Out:
# Cloning into 'Hierarchical-Clustering-of-a-Mixture-Model'...
# remote: Enumerating objects: 1195, done.
# remote: Counting objects: 100% (1195/1195), done.
# remote: Compressing objects: 100% (1172/1172), done.
# remote: Total 1195 (delta 96), reused 1069 (delta 20), pack-reused 0
# Receiving objects: 100% (1195/1195), 31.22 MiB | 26.29 MiB/s, done.
# Resolving deltas: 100% (96/96), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/Hierarchical-Clustering-of-a-Mixture-Model/AHC-GMM/mylib/Clustering.py'
# Out:
# /content/Hierarchical-Clustering-of-a-Mixture-Model/AHC-GMM/mylib/Clustering.py

# %%
# !cat  '/content/Hierarchical-Clustering-of-a-Mixture-Model/AHC-GMM/mylib/Clustering.py'
# Out:
# # library mathematic & statistic
# import numpy as np
# from scipy.stats import multivariate_normal
# from scipy import linalg
# from numpy.linalg import multi_dot
# from sklearn.mixture.base import BaseMixture, _check_shape
# from sklearn.utils import check_array, check_random_state
# import warnings
# # library for machine learning
# from sklearn.cluster import KMeans
# from sklearn.mixture import GaussianMixture
# np.seterr(divide='ignore', invalid='ignore')
#
# def Kullback_Leibler_Distance(GMM1 , GMM2 ):
#   Means_1 , Covars_1 = GMM1
#   Means_2 , Covars_2 = GMM2
#   Covars_1 =  numpy_cholesky(Covars_1)
#   Covars_2 =  numpy_cholesky(Covars_2)
#   Det = np.log(np.abs( det_cholesky(Covars_2)/det_cholesky(Covars_1)[:, np.newaxis]))
#   inv_S = inv_cholesky(Covars_2 )
#   n_clusters_2 , n_features = Means_2.shape ;  n_clusters_1 = Means_1.shape[0] ; dis = np.empty((n_clusters_1, n_clusters_2))
#   for k in range(n_clusters_2):
#     dif_mu  = Means_1-Means_2[k]
# ...

# %%
import sys
sys.path.append('/content/Hierarchical-Clustering-of-a-Mixture-Model/AHC-GMM')

# %%
from mylib.Clustering import Hierarchical_Mixture_Model
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.mixture.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.mixture. Anything that cannot be imported from sklearn.mixture is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from sklearn.datasets import make_blobs
k = 10
X, y = make_blobs(n_samples=1000, centers=10, n_features=2,
                  random_state=0)

# %%
import numpy as np
from sklearn.mixture import GaussianMixture 
labels = []
for j in A :
  labels.append( GaussianMixture(n_components = j+1 , random_state=0).fit( X  ).predict(X)  )
labels = np.array(labels)

# %%
A = np.arange(40)[11 : 22 ]

# %%
fig = plt.figure(figsize=(14, 6)) 
fig.subplots_adjust(left=0, right=1, bottom=0, top=1 , hspace=0.1, wspace=0.05)
for i in range(10):
    ax = fig.add_subplot(2, 5, i + 1, xticks=[], yticks=[])
    ax.scatter( X[:, 0] , X[:, 1] , c = labels[i] , cmap= 'viridis' )
    ax.set_title(f'n_composents : {i+11}')

# %%
labels_hcmm = []
for j in A :
  labels_hcmm.append( Hierarchical_Mixture_Model( j+1 , 10 ).fit( X  ).predict(X)  )
labels_hcmm = np.array(labels_hcmm)

# %%
fig = plt.figure(figsize=(14, 6)) 
fig.subplots_adjust(left=0, right=1, bottom=0, top=1 , hspace=0.1, wspace=0.05)
import matplotlib.pyplot as plt
h = 0
style = ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast',
 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 
 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 
 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
h =9 # 9
plt.style.use(style[h])
for i in range(10):
    ax = fig.add_subplot(2, 5, i + 1, xticks=[], yticks=[])
    ax.scatter( X[:, 0] , X[:, 1] , c = labels_hcmm[i] , cmap= 'viridis' )
    ax.set_title(f'  {i+11}' ' to 10 n_composents')

# %%
import matplotlib.pyplot as plt
h = 0
style = ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast',
 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 
 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 
 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
plt.style.use(style[h])

# %%
from sklearn.datasets import make_blobs
k = 50
X, y = make_blobs(n_samples=10000, centers=10, n_features=2, random_state=0)

# %%
import time 
t = []
M = 100
for i in range(M):
  start = time.time()
  labels = GaussianMixture(n_components = i+1 , random_state=0).fit( X  ).predict(X)
  end = time.time()
  t.append(end-start)

# %%
plt.plot( range(M) , t )
plt.ylabel('running time (s) ')
plt.xlabel('n_composents ')
plt.show()

# %%
max(t)
# Out:
# 1.9177193641662598
